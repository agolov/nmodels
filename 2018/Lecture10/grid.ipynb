# %%
import numpy as np
from scipy.spatial import Delaunay
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %pylab inline
pylab.rcParams['figure.figsize']=(7,7)

def get_radius(r):
    n_pts = 10
    step = 180/n_pts
    pts = []
    for i in range(n_pts+1):
        y =  r*np.cos(np.pi*i*step/180)
        x =  r*np.sin(np.pi*i*step/180)
        pts.append([x, y])
        pts.append([-x, y])
    return pts


points = []
for r in range(5,7,1):
    points.extend(get_radius(r))

points = np.array(points)
tri = Delaunay(points)

plt.triplot(points[:,0], points[:,1], tri.vertices)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tri.simplices
tri.points
# Out:
# array([[  0.00000000e+00,   5.00000000e+00],
#        [ -0.00000000e+00,   5.00000000e+00],
#        [  1.54508497e+00,   4.75528258e+00],
#        [ -1.54508497e+00,   4.75528258e+00],
#        [  2.93892626e+00,   4.04508497e+00],
#        [ -2.93892626e+00,   4.04508497e+00],
#        [  4.04508497e+00,   2.93892626e+00],
#        [ -4.04508497e+00,   2.93892626e+00],
#        [  4.75528258e+00,   1.54508497e+00],
#        [ -4.75528258e+00,   1.54508497e+00],
#        [  5.00000000e+00,   3.06161700e-16],
#        [ -5.00000000e+00,   3.06161700e-16],
#        [  4.75528258e+00,  -1.54508497e+00],
#        [ -4.75528258e+00,  -1.54508497e+00],
#        [  4.04508497e+00,  -2.93892626e+00],
#        [ -4.04508497e+00,  -2.93892626e+00],
#        [  2.93892626e+00,  -4.04508497e+00],
#        [ -2.93892626e+00,  -4.04508497e+00],
#        [  1.54508497e+00,  -4.75528258e+00],
#        [ -1.54508497e+00,  -4.75528258e+00],
#        [  6.12323400e-16,  -5.00000000e+00],
#        [ -6.12323400e-16,  -5.00000000e+00],
#        [  0.00000000e+00,   6.00000000e+00],
#        [ -0.00000000e+00,   6.00000000e+00],
#        [  1.85410197e+00,   5.70633910e+00],
#        [ -1.85410197e+00,   5.70633910e+00],
#        [  3.52671151e+00,   4.85410197e+00],
#        [ -3.52671151e+00,   4.85410197e+00],
#        [  4.85410197e+00,   3.52671151e+00],
#        [ -4.85410197e+00,   3.52671151e+00],
#        [  5.70633910e+00,   1.85410197e+00],
#        [ -5.70633910e+00,   1.85410197e+00],
#        [  6.00000000e+00,   3.67394040e-16],
#        [ -6.00000000e+00,   3.67394040e-16],
#        [  5.70633910e+00,  -1.85410197e+00],
#        [ -5.70633910e+00,  -1.85410197e+00],
#        [  4.85410197e+00,  -3.52671151e+00],
#        [ -4.85410197e+00,  -3.52671151e+00],
#        [  3.52671151e+00,  -4.85410197e+00],
#        [ -3.52671151e+00,  -4.85410197e+00],
#        [  1.85410197e+00,  -5.70633910e+00],
#        [ -1.85410197e+00,  -5.70633910e+00],
#        [  7.34788079e-16,  -6.00000000e+00],
#        [ -7.34788079e-16,  -6.00000000e+00]])
