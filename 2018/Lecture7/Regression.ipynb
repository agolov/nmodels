# %%
mylist = [1, 4, -5, 10, -7, 2, 3, -1]
print([n for n in mylist if n > 0])
print([n for n in mylist if n < 0])
# Out:
# [1, 4, 10, 2, 3]
# [-5, -7, -1]

# %%
arr=[12,45,67,89]

b=0

i=1
for a in arr:
    b+=a*i
    i+=1
    
for i in range(len(arr)):
    b+=arr[i]*i   
    
for i,a in enumerate(arr):
    b+=a*i

# %%
from collections import defaultdict

d3={}

if 'a' in d3:
    d3['a']+=1
else:
    d3['a']=1

d2=defaultdict(int)
d2['a']+=1  

d = defaultdict(list)
d['a'].append(1)
d['a'].append(2)
d['b'].append(4)

# %%
from collections import Counter

words = [
'look', 'into', 'my', 'eyes', 'look', 'into', 'my', 'eyes',
'the', 'eyes', 'the', 'eyes', 'the', 'eyes', 'not', 'around', 'the',
'eyes', "don't", 'look', 'around', 'the', 'eyes', 'look', 'into',
'my', 'eyes', "you're", 'under'
]

word_counts = Counter(words)
top_three = word_counts.most_common(3)
print(top_three)
print(word_counts['the'])
# Out:
# [('eyes', 8), ('the', 5), ('look', 4)]
# 5

# %%
from collections import namedtuple

Subscriber = namedtuple('Subscriber', ['addr', 'joined'])
sub = Subscriber('jonesy@example.com', '2012-10-19')
print(sub.addr, sub.joined)
# Out:
# jonesy@example.com 2012-10-19

# %%
import numpy as np
from sklearn.linear_model import LinearRegression 
from sklearn.linear_model import ElasticNetCV 
from sklearn.linear_model import LassoCV 
from sklearn.linear_model import RidgeCV 
from sklearn.model_selection import cross_val_score 
import matplotlib.pyplot as plt
# %pylab inline
pylab.rcParams['figure.figsize'] = (13, 6)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
np.random.seed(42)
n_samples, n_features = 500, 300
X = np.random.randn(n_samples, n_features)

coef = 15 * np.random.randn(n_features)

# %%
y = np.dot(X, coef)
y *= (1-0.5 * np.random.rand(n_samples))

# %%
import scipy.stats as stats
import statsmodels.api as sm

reg_lr = LinearRegression()
error_lr = np.abs(cross_val_score(reg_lr, X, y, cv=5)).mean()
print(error_lr)
reg_lr.fit(X,y)

plt.plot(coef)
plt.plot(reg_lr.coef_)
plt.show()

y_pred=reg_lr.predict(X)
plt.plot(y-y_pred)
plt.show()
res=stats.probplot(y-y_pred, plot=plt)
plt.show()
model = sm.OLS(y,X)
results = model.fit()
results.summary()
# Out:
# 0.89607768983
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     53.61
# Date:                Tue, 03 Apr 2018   Prob (F-statistic):          3.23e-145
# Time:                        23:00:07   Log-Likelihood:                -2261.7
# No. Observations:                 500   AIC:                             5023.
# Df Residuals:                     250   BIC:                             6077.
# Df Model:                         250
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
coef[inds[200:]] = 0  
y = np.dot(X, coef)
y *= (1-0.5 * np.random.rand(n_samples))

# %%
y-reg_lr.predict(x)
