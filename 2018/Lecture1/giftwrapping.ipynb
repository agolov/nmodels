# %%
import numpy as np
import matplotlib.pyplot as plt 
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
n=20
x = np.random.randn(n)
y = np.random.randn(n)
x,y
# Out:
# (array([-0.20762322, -0.74590113,  0.0284448 ,  0.3836061 ,  0.26731307,
#         -0.30103505,  0.16748791,  0.20905568, -1.00589302, -0.05810777,
#         -1.99774603,  0.45699319, -1.49465464,  1.14947947, -0.51495184,
#          0.37048289,  0.91377414, -0.56768391, -0.54308518, -0.43921171]),
#  array([ 0.22352747,  1.03406456,  0.87454153, -0.15643516,  0.7488426 ,
#          0.5163239 , -0.27092548, -0.60003037, -0.25740959,  1.18911985,
#          0.15209414,  0.59507119,  0.10245574, -0.63162977, -1.10481149,
#          1.17935294,  2.04635482, -0.73657713,  0.68060505, -0.11499805]))

# %%
plt.scatter(x,y) 
plt.show()

# %%
def getCos(x1, y1, x2, y2):
    return (x1*x2+y1*y2)/(sqrt(x1**2+y1**2)*sqrt(x2**2+y2**2))

# %%
xNew = x[convex]
yNew = y[convex]
print(xNew)
print(yNew)
# Out:
# [-1.99774603 -0.74590113  0.91377414  1.14947947 -0.51495184 -1.99774603]
# [ 0.15209414  1.03406456  2.04635482 -0.63162977 -1.10481149  0.15209414]

# %%
xConv = x[convex]
yConv = y[convex]
plt.plot(xConv,yConv)
plt.scatter(x,y) 
plt.show()
